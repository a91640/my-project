# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ghula\my-project\.venv\Scripts\python.exe

# %%
import langchain
import chromadb
import pypdf

print("LangChain:", langchain.__version__)
print("ChromaDB:", chromadb.__version__)
print("RAG environment is ready!")
# Out:
# LangChain: 1.3.15
# ChromaDB: 1.5.9
# RAG environment is ready!

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_path = "data/Sample.pdf"
loader = PyPDFLoader(pdf_path)
documents = loader.load()

print("PDF loaded successfully!")
print("Number of pages:", len(documents))
# Out:
# C:\Users\ghula\AppData\Local\Temp\ipykernel_26188\1587407288.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# PDF loaded successfully!
# Number of pages: 67

# %%
print(documents[0].page_content[:1000])
# Out:
# Retrieval-Augmented Generation for Natural
# Language Processing: A Survey
# Shangyu Wu1,2, Ying Xiong2†, Yufei Cui3, Haolun Wu3, Can
# Chen3, Ye Yuan3, Lianming Huang1, Xue Liu2, Tei-Wei Kuo4,
# Nan Guan1, Chun Jason Xue2
# 1City University of Hong Kong.
# 2Mohamed bin Zayed University of Artificial Intelligence.
# 3McGill University, Mila.
# 4National Taiwan University.
# †Corresponding author.
# Abstract
# Large language models (LLMs) have achieved strong empirical performance in
# various fields, benefiting from their huge amount of parameters that store knowl-
# edge. However, LLMs still suffer from several key issues, such as hallucination
# problems, knowledge update issues, and lacking domain-specific expertise. The
# appearance of retrieval-augmented generation (RAG), which leverages an exter-
# nal knowledge base to augment LLMs, mitigates these limitations. This paper
# presents a systematic review of RAG techniques for natural language process-
# ing (NLP), with a focus on retrievers and retrieval fusions. We

# %%
print(documents[0].metadata)
# Out:
# {'producer': 'pikepdf 8.15.1', 'creator': 'arXiv GenPDF (tex2pdf:a6404ea)', 'creationdate': '', 'author': 'Shangyu Wu; Ying Xiong; Yufei Cui; Haolun Wu; Can Chen; Ye Yuan; Lianming Huang; Xue Liu; Tei-Wei Kuo; Nan Guan; Chun Jason Xue', 'doi': 'https://doi.org/10.48550/arXiv.2407.13193', 'license': 'http://creativecommons.org/licenses/by/4.0/', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.28 (TeX Live 2025) kpathsea version 6.4.1', 'title': 'Retrieval-Augmented Generation for Natural Language Processing: A Survey', 'trapped': '/False', 'arxivid': 'https://arxiv.org/abs/2407.13193v4', 'source': 'data/Sample.pdf', 'total_pages': 67, 'page': 0, 'page_label': '1'}

# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello")
# Out:
# Hello

# %%
import langchain
import chromadb

print(langchain.__version__)
print(chromadb.__version__)
# Out:
# 1.3.15
# 1.5.9

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print("Number of pages:", len(documents))
print("Number of chunks:", len(chunks))
# Out:
# Number of pages: 67
# Number of chunks: 243

# %%
print(chunks[0].page_content)
# Out:
# Retrieval-Augmented Generation for Natural
# Language Processing: A Survey
# Shangyu Wu1,2, Ying Xiong2†, Yufei Cui3, Haolun Wu3, Can
# Chen3, Ye Yuan3, Lianming Huang1, Xue Liu2, Tei-Wei Kuo4,
# Nan Guan1, Chun Jason Xue2
# 1City University of Hong Kong.
# 2Mohamed bin Zayed University of Artificial Intelligence.
# 3McGill University, Mila.
# 4National Taiwan University.
# †Corresponding author.
# Abstract
# Large language models (LLMs) have achieved strong empirical performance in
# various fields, benefiting from their huge amount of parameters that store knowl-
# edge. However, LLMs still suffer from several key issues, such as hallucination
# problems, knowledge update issues, and lacking domain-specific expertise. The
# appearance of retrieval-augmented generation (RAG), which leverages an exter-
# nal knowledge base to augment LLMs, mitigates these limitations. This paper
# presents a systematic review of RAG techniques for natural language process-

# %%
print(chunks[0].metadata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(chunks[0].metadata)
#
# NameError: name 'chunks' is not defined

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_path = "data/Sample.pdf"

loader = PyPDFLoader(pdf_path)
documents = loader.load()

print("Pages:", len(documents))
# Out:
# C:\Users\ghula\AppData\Local\Temp\ipykernel_7132\3530899011.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# Pages: 67

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print("Number of pages:", len(documents))
print("Number of chunks:", len(chunks))
# Out:
# Number of pages: 67
# Number of chunks: 243

# %%
print(chunks[0].page_content)
# Out:
# Retrieval-Augmented Generation for Natural
# Language Processing: A Survey
# Shangyu Wu1,2, Ying Xiong2†, Yufei Cui3, Haolun Wu3, Can
# Chen3, Ye Yuan3, Lianming Huang1, Xue Liu2, Tei-Wei Kuo4,
# Nan Guan1, Chun Jason Xue2
# 1City University of Hong Kong.
# 2Mohamed bin Zayed University of Artificial Intelligence.
# 3McGill University, Mila.
# 4National Taiwan University.
# †Corresponding author.
# Abstract
# Large language models (LLMs) have achieved strong empirical performance in
# various fields, benefiting from their huge amount of parameters that store knowl-
# edge. However, LLMs still suffer from several key issues, such as hallucination
# problems, knowledge update issues, and lacking domain-specific expertise. The
# appearance of retrieval-augmented generation (RAG), which leverages an exter-
# nal knowledge base to augment LLMs, mitigates these limitations. This paper
# presents a systematic review of RAG techniques for natural language process-

# %%
print(chunks[0].metadata)
# Out:
# {'producer': 'pikepdf 8.15.1', 'creator': 'arXiv GenPDF (tex2pdf:a6404ea)', 'creationdate': '', 'author': 'Shangyu Wu; Ying Xiong; Yufei Cui; Haolun Wu; Can Chen; Ye Yuan; Lianming Huang; Xue Liu; Tei-Wei Kuo; Nan Guan; Chun Jason Xue', 'doi': 'https://doi.org/10.48550/arXiv.2407.13193', 'license': 'http://creativecommons.org/licenses/by/4.0/', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.28 (TeX Live 2025) kpathsea version 6.4.1', 'title': 'Retrieval-Augmented Generation for Natural Language Processing: A Survey', 'trapped': '/False', 'arxivid': 'https://arxiv.org/abs/2407.13193v4', 'source': 'data/Sample.pdf', 'total_pages': 67, 'page': 0, 'page_label': '1'}

# %%
from langchain_openai import OpenAIEmbeddings

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

if api_key:
    print("OpenAI API key found!")
else:
    print("OpenAI API key NOT found")
# Out:
# OpenAI API key NOT found

# %%
import os

print(os.getcwd())
print(os.path.exists(".env"))
# Out:
# c:\Users\ghula\my-project
# True
